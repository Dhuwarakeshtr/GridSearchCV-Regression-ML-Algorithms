# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.replace({True:0,False:1})
# Out:
# C:\Users\gowth\AppData\Local\Temp\ipykernel_75140\1492029577.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset=dataset.replace({True:0,False:1})

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 
            'splitter':['best', 'random'], 'max_features':['sqrt', 'log2']}
regressor=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
regressor.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
print("The r_score value for best paramete {} :".format(regressor.best_params_),r_score)
# Out:
# The r_score value for best paramete {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'} : 0.6278154274257286

# %%
result=regressor.cv_results_

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011366      0.002602         0.005103        0.000655
# 1        0.007499      0.001087         0.005966        0.004012
# 2        0.008446      0.001044         0.005425        0.002149
# 3        0.006801      0.000635         0.004302        0.001039
# 4        0.008335      0.001766         0.003946        0.000434
# 5        0.006072      0.000293         0.003737        0.000346
# 6        0.006957      0.000462         0.004198        0.000857
# 7        0.007433      0.003361         0.003623        0.000516
# 8        0.022483      0.004429         0.003200        0.000153
# 9        0.014259      0.000816         0.003478        0.000403
# 10       0.022403      0.003164         0.003765        0.000267
# 11       0.016055      0.001176         0.004470        0.001173
# 12       0.007366      0.000234         0.004846        0.002703
# 13       0.009441      0.002030         0.003644        0.000368
# 14       0.010596      0.001196         0.003778        0.000457
# 15       0.006949      0.000728         0.003867        0.000238
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.369630
# 1   {'criterion': 'squared_error', 'max_features':...           0.711762
# 2   {'criterion': 'squared_error', 'max_features':...           0.651699
# 3   {'criterion': 'squared_error', 'max_features':...           0.507288
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.729417
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.696522
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.665370
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.737433
# 8   {'criterion': 'absolute_error', 'max_features'...           0.579949
# 9   {'criterion': 'absolute_error', 'max_features'...           0.469433
# 10  {'criterion': 'absolute_error', 'max_features'...           0.526107
# 11  {'criterion': 'absolute_error', 'max_features'...           0.710245
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.340040
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.596883
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.725673
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.579164
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.601023           0.599121           0.725226
# 1            0.613845           0.611458           0.589669
# 2            0.435025           0.703450           0.643082
# 3            0.613156           0.508091           0.541693
# 4            0.427767           0.634745           0.493379
# 5            0.650743           0.697638           0.639994
# 6            0.566193           0.405008           0.627436
# 7            0.607871           0.563991           0.559606
# 8            0.472003           0.267222           0.559939
# 9            0.590020           0.651207           0.536663
# 10           0.622478           0.630377           0.719884
# 11           0.569133           0.638016           0.491381
# 12           0.641017           0.674764           0.558520
# 13           0.638448           0.589506           0.504720
# 14           0.593722           0.544378           0.620411
# 15           0.605824           0.507898           0.577483
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.687504         0.596501        0.123571                7
# 1            0.624748         0.630296        0.042293                4
# 2            0.612471         0.609145        0.091853                6
# 3            0.480411         0.530128        0.045840               15
# 4            0.680999         0.593261        0.114299                8
# 5            0.576909         0.652361        0.044382                1
# 6            0.686131         0.590028        0.101106               11
# 7            0.491776         0.592135        0.081586                9
# 8            0.542338         0.484290        0.114466               16
# 9            0.668503         0.583165        0.073562               12
# 10           0.666663         0.633102        0.063601                3
# 11           0.666641         0.615083        0.077011                5
# 12           0.614021         0.565672        0.119060               14
# 13           0.573729         0.580657        0.043580               13
# 14           0.702704         0.637378        0.067685                2
# 15           0.684581         0.590990        0.056931               10

# %%
Age=float(input("Age ="))
BMI=float(input("BMI ="))
Children=input("Children =")
Sex=int(input("Sex 0 or 1 ="))
Smoke=int(input("Smoke 0 or 1 ="))
# Out:
# Age = 38
# BMI = 40.15
# Children = 0
# Sex 0 or 1 = 1
# Smoke 0 or 1 = 1

# %%
future_pred=regressor.predict([[Age,BMI,Children,Sex,Smoke]])
print("Future Prediction {}".format(future_pred))
# Out:
# Future Prediction [1163.4627]
